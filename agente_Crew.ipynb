# %% [markdown]
# <a href="https://colab.research.google.com/github/trafaon/estudo_agente/blob/main/agente_Crew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install - requirements.txt

# %%
# Instala CrewAI com ferramentas
# !pip install -U 'crewai[tools]'

# Instala CrewAI udemy
# !wget -qO- https://astral.sh/uv/install.sh | sh

# !uv tool install crewai

# !uv tool install crewai --upgrade

# !uv tool list

# !uv tool update-shell

# !crewai create crew newsletter_agent

# !crewai install
# Out:
# Collecting crewai[tools]
#   Downloading crewai-0.118.0-py3-none-any.whl.metadata (33 kB)
# Collecting appdirs>=1.4.4 (from crewai[tools])
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai[tools])
#   Downloading auth0_python-4.9.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (1.9.0)
# Collecting chromadb>=0.5.23 (from crewai[tools])
#   Downloading chromadb-1.0.7-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (8.1.8)
# Collecting instructor>=1.3.3 (from crewai[tools])
#   Downloading instructor-1.7.9-py3-none-any.whl.metadata (22 kB)
# Collecting json-repair>=0.25.2 (from crewai[tools])
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Collecting json5>=0.10.0 (from crewai[tools])
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Collecting jsonref>=1.1.0 (from crewai[tools])
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.67.1 (from crewai[tools])
#   Downloading litellm-1.67.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (1.76.0)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (3.1.5)
# Collecting opentelemetry-api>=1.30.0 (from crewai[tools])
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from crewai[tools])
#   Downloading opentelemetry_exporter_otlp_proto_http-1.32.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.30.0 (from crewai[tools])
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pdfplumber>=0.11.4 (from crewai[tools])
#   Downloading pdfplumber-0.11.6-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (2.11.3)
# Collecting python-dotenv>=1.0.0 (from crewai[tools])
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting pyvis>=0.3.2 (from crewai[tools])
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai[tools]) (2024.11.6)
# Collecting tomli-w>=1.1.0 (from crewai[tools])
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai[tools])
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai[tools])
#   Downloading uv-0.7.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting crewai-tools~=0.42.2 (from crewai[tools])
#   Downloading crewai_tools-0.42.2-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (3.11.15)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (4.23.0)
# Collecting tiktoken>=0.7.0 (from litellm==1.67.1->crewai[tools])
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm==1.67.1->crewai[tools]) (0.21.1)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai[tools]) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai[tools]) (2.10.1)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai[tools]) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai[tools]) (2.4.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (1.2.2.post1)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.23->crewai[tools])
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi==0.115.9 (from chromadb>=0.5.23->crewai[tools])
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools])
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai[tools])
#   Downloading posthog-4.0.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (4.13.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.23->crewai[tools])
#   Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai[tools])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.23->crewai[tools])
#   Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl.metadata (2.2 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai[tools])
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai[tools])
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai[tools])
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (0.15.3)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai[tools])
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai[tools])
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (3.10.17)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai[tools]) (13.9.4)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb>=0.5.23->crewai[tools])
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting docker>=7.1.0 (from crewai-tools~=0.42.2->crewai[tools])
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting embedchain>=0.1.114 (from crewai-tools~=0.42.2->crewai[tools])
#   Downloading embedchain-0.1.128-py3-none-any.whl.metadata (9.2 kB)
# Collecting lancedb>=0.5.4 (from crewai-tools~=0.42.2->crewai[tools])
#   Downloading lancedb-0.22.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting pyright>=1.1.350 (from crewai-tools~=0.42.2->crewai[tools])
#   Downloading pyright-1.1.400-py3-none-any.whl.metadata (6.6 kB)
# Collecting pytube>=15.0.0 (from crewai-tools~=0.42.2->crewai[tools])
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai[tools]) (0.16)
# Collecting jiter<0.9,>=0.6.1 (from instructor>=1.3.3->crewai[tools])
#   Downloading jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai[tools]) (2.33.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai[tools]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai[tools]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai[tools]) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai[tools]) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.30.0->crewai[tools]) (1.2.18)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.67.1->crewai[tools])
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai[tools]) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai[tools])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.32.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai[tools])
#   Downloading opentelemetry_proto-1.32.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-proto==1.32.1->opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai[tools]) (5.29.4)
# Collecting opentelemetry-semantic-conventions==0.53b1 (from opentelemetry-sdk>=1.30.0->crewai[tools])
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pdfminer.six==20250327 (from pdfplumber>=0.11.4->crewai[tools])
#   Downloading pdfminer_six-20250327-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai[tools]) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai[tools])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 574.7 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250327->pdfplumber>=0.11.4->crewai[tools]) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai[tools]) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai[tools]) (0.4.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai[tools]) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai[tools]) (4.0.5)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai[tools]) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.67.1->crewai[tools]) (1.20.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai[tools]) (3.10)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai[tools]) (24.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai[tools]) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai[tools]) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.30.0->crewai[tools]) (1.17.2)
# Collecting alembic<2.0.0,>=1.13.1 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (4.13.4)
# Collecting chromadb>=0.5.23 (from crewai[tools])
#   Downloading chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting gptcache<0.2.0,>=0.1.43 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading gptcache-0.1.44-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.3.24)
# Collecting langchain-cohere<0.4.0,>=0.3.0 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading langchain_cohere-0.3.5-py3-none-any.whl.metadata (6.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading langchain_community-0.3.23-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-openai<0.3.0,>=0.2.1 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langsmith<0.4.0,>=0.3.18 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.3.38)
# Collecting mem0ai<0.2.0,>=0.1.54 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading mem0ai-0.1.96-py3-none-any.whl.metadata (7.4 kB)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai[tools])
#   Downloading posthog-3.25.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting pypdf<6.0.0,>=5.0.0 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pysbd<0.4.0,>=0.3.4 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting schema<0.8.0,>=0.7.5 (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading schema-0.7.7-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (2.0.40)
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.23->crewai[tools])
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting tokenizers (from litellm==1.67.1->crewai[tools])
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm==1.67.1->crewai[tools]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm==1.67.1->crewai[tools]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.67.1->crewai[tools]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.67.1->crewai[tools]) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.67.1->crewai[tools]) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.67.1->crewai[tools]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.67.1->crewai[tools]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.67.1->crewai[tools]) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools])
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting deprecation (from lancedb>=0.5.4->crewai-tools~=0.42.2->crewai[tools])
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyarrow>=14 in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools~=0.42.2->crewai[tools]) (18.1.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai[tools])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai[tools]) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai[tools]) (1.13.1)
# Collecting opentelemetry-instrumentation-asgi==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools])
#   Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools])
#   Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-util-http==0.53b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools])
#   Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools])
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools])
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools])
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting nodeenv>=1.6.0 (from pyright>=1.1.350->crewai-tools~=0.42.2->crewai[tools])
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai[tools]) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm==1.67.1->crewai[tools]) (0.30.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai[tools]) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools])
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools])
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools])
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools]) (15.0.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (1.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai[tools]) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.67.1->crewai[tools]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.67.1->crewai[tools]) (2025.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.8.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.3.56)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.3.8)
# Collecting cohere<6.0,>=5.5.6 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading cohere-5.15.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-experimental<0.4.0,>=0.3.0 (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.9.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (0.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai[tools]) (0.1.2)
# Collecting pytz<2025.0,>=2024.1 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting qdrant-client<2.0.0,>=1.9.1 (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading qdrant_client-1.14.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.2.13)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (3.2.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai[tools])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai[tools]) (1.3.0)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading types_requests-2.32.0.20250328-py3-none-any.whl.metadata (2.3 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (1.33)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (2025.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (0.6.1)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (4.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools])
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.42.2->crewai[tools]) (4.1.0)
# Downloading litellm-1.67.1-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 68.0 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading auth0_python-4.9.0-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 9.4 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.1 MB/s eta 0:00:00
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.6 MB/s eta 0:00:00
# Downloading crewai_tools-0.42.2-py3-none-any.whl (583 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.9/583.9 kB 36.4 MB/s eta 0:00:00
# Downloading crewai-0.118.0-py3-none-any.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 20.7 MB/s eta 0:00:00
# Downloading instructor-1.7.9-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.0 MB/s eta 0:00:00
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 4.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.32.1-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.32.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.2 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 8.9 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 12.8 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.6-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 3.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20250327-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 86.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 39.5 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 17.0 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading uv-0.7.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 89.1 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.6 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.8 MB/s eta 0:00:00
# Downloading embedchain-0.1.128-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 14.2 MB/s eta 0:00:00
# Downloading chromadb-0.5.23-py3-none-any.whl (628 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 38.4 MB/s eta 0:00:00
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 22.5 MB/s eta 0:00:00
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.7 MB/s eta 0:00:00
# Downloading lancedb-0.22.0-cp39-abi3-manylinux_2_28_x86_64.whl (33.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 22.0 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 84.1 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl (7.3 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.25.0-py2.py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 6.3 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 71.6 MB/s eta 0:00:00
# Downloading pyright-1.1.400-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 69.6 MB/s eta 0:00:00
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.0 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.9 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 61.1 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.4 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 13.9 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading gptcache-0.1.44-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 5.5 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 17.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.4 MB/s eta 0:00:00
# Downloading langchain_cohere-0.3.5-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.3 MB/s eta 0:00:00
# Downloading langchain_community-0.3.23-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.7 MB/s eta 0:00:00
# Downloading langchain_openai-0.2.14-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.9 MB/s eta 0:00:00
# Downloading mem0ai-0.1.96-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.8/142.8 kB 9.6 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 20.6 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.7 MB/s eta 0:00:00
# Downloading schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 4.6 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 57.5 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 24.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading cohere-5.15.0-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 17.5 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00
# Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 15.5 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 24.3 MB/s eta 0:00:00
# Downloading qdrant_client-1.14.2-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.7/327.7 kB 17.2 MB/s eta 0:00:00
# Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 65.2 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading types_requests-2.32.0.20250328-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53801 sha256=ba64cc8d472b045571b9871839a97bb87b3849c6d66962c952385ab877fe2d70
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: schema, pytz, pypika, monotonic, durationpy, appdirs, uvloop, uvicorn, uv, types-requests, tomli-w, tomli, pytube, python-dotenv, pysbd, pypdfium2, pypdf, portalocker, overrides, opentelemetry-util-http, opentelemetry-proto, nodeenv, mypy-extensions, mmh3, marshmallow, jsonref, json5, json-repair, jiter, jedi, importlib-metadata, humanfriendly, httpx-sse, httptools, fastavro, deprecation, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, typing-inspect, tiktoken, starlette, pyright, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, gptcache, docker, coloredlogs, alembic, tokenizers, pyvis, pydantic-settings, pdfminer.six, opentelemetry-semantic-conventions, onnxruntime, lancedb, kubernetes, fastapi, dataclasses-json, auth0-python, qdrant-client, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, litellm, instructor, cohere, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mem0ai, langchain-openai, opentelemetry-instrumentation-fastapi, langchain-community, chromadb, langchain-experimental, crewai, langchain-cohere, embedchain, crewai-tools
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.9.0
#     Uninstalling jiter-0.9.0:
#       Successfully uninstalled jiter-0.9.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.16.0
#     Uninstalling opentelemetry-api-1.16.0:
#       Successfully uninstalled opentelemetry-api-1.16.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.37b0
#     Uninstalling opentelemetry-semantic-conventions-0.37b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.37b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.16.0
#     Uninstalling opentelemetry-sdk-1.16.0:
#       Successfully uninstalled opentelemetry-sdk-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.51.3 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.
# Successfully installed alembic-1.15.2 appdirs-1.4.4 asgiref-3.8.1 auth0-python-4.9.0 backoff-2.2.1 bcrypt-4.3.0 chroma-hnswlib-0.7.6 chromadb-0.5.23 cohere-5.15.0 coloredlogs-15.0.1 crewai-0.118.0 crewai-tools-0.42.2 dataclasses-json-0.6.7 deprecation-2.1.0 docker-7.1.0 durationpy-0.9 embedchain-0.1.128 fastapi-0.115.9 fastavro-1.10.0 gptcache-0.1.44 httptools-0.6.4 httpx-sse-0.4.0 humanfriendly-10.0 importlib-metadata-8.6.1 instructor-1.7.9 jedi-0.19.2 jiter-0.8.2 json-repair-0.44.1 json5-0.12.0 jsonref-1.1.0 kubernetes-32.0.1 lancedb-0.22.0 langchain-cohere-0.3.5 langchain-community-0.3.23 langchain-experimental-0.3.4 langchain-openai-0.2.14 litellm-1.67.1 marshmallow-3.26.1 mem0ai-0.1.96 mmh3-5.1.0 monotonic-1.6 mypy-extensions-1.1.0 nodeenv-1.9.1 onnxruntime-1.21.1 opentelemetry-api-1.32.1 opentelemetry-exporter-otlp-proto-common-1.32.1 opentelemetry-exporter-otlp-proto-grpc-1.32.1 opentelemetry-exporter-otlp-proto-http-1.32.1 opentelemetry-instrumentation-0.53b1 opentelemetry-instrumentation-asgi-0.53b1 opentelemetry-instrumentation-fastapi-0.53b1 opentelemetry-proto-1.32.1 opentelemetry-sdk-1.32.1 opentelemetry-semantic-conventions-0.53b1 opentelemetry-util-http-0.53b1 overrides-7.7.0 pdfminer.six-20250327 pdfplumber-0.11.6 portalocker-2.10.1 posthog-3.25.0 pydantic-settings-2.9.1 pypdf-5.4.0 pypdfium2-4.30.1 pypika-0.48.9 pyright-1.1.400 pysbd-0.3.4 python-dotenv-1.1.0 pytube-15.0.0 pytz-2024.2 pyvis-0.3.2 qdrant-client-1.14.2 schema-0.7.7 starlette-0.45.3 tiktoken-0.9.0 tokenizers-0.20.3 tomli-2.2.1 tomli-w-1.2.0 types-requests-2.32.0.20250328 typing-inspect-0.9.0 uv-0.7.2 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5
# A saída de streaming foi truncada nas últimas 5000 linhas.
# orjson     ------------------------------ 103.32 KiB/129.69 KiB
# jinja2     ------------------------------ 62.88 KiB/131.74 KiB
# auth0-python ------------------------------ 14.91 KiB/132.18 KiB
# charset-normalizer ------------------------------ 125.68 KiB/143.81 KiB
# oauthlib   ------------------------------ 62.34 KiB/148.13 KiB
# certifi    ------------------------------ 155.88 KiB/155.88 KiB
# ...
# numpy      ------------------------------ 5.83 MiB/15.67 MiB
# uv         ------------------------------ 7.12 MiB/16.57 MiB
# ⠸ Preparing packages... (141/148)
# jedi       ------------------------------ 869.09 KiB/1.50 MiB
# sympy      ------------------------------ 3.85 MiB/6.01 MiB
# litellm    ------------------------------ 6.43 MiB/7.25 MiB
# onnxruntime ------------------------------ 7.36 MiB/15.26 MiB
# numpy      ------------------------------ 5.94 MiB/15.67 MiB
# uv         ------------------------------ 7.29 MiB/16.57 MiB
# ⠼ Preparing packages... (141/148)
# jedi       ------------------------------ 869.09 KiB/1.50 MiB
# sympy      ------------------------------ 4.04 MiB/6.01 MiB
# litellm    ------------------------------ 6.91 MiB/7.25 MiB
# onnxruntime ------------------------------ 7.54 MiB/15.26 MiB
# numpy      ------------------------------ 6.03 MiB/15.67 MiB
# uv         ------------------------------ 7.46 MiB/16.57 MiB
# ⠼ Preparing packages... (141/148)
# jedi       ------------------------------ 911.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.07 MiB/6.01 MiB
# litellm    ------------------------------ 7.02 MiB/7.25 MiB
# onnxruntime ------------------------------ 7.92 MiB/15.26 MiB
# numpy      ------------------------------ 6.14 MiB/15.67 MiB
# uv         ------------------------------ 7.71 MiB/16.57 MiB
# ⠼ Preparing packages... (141/148)
# jedi       ------------------------------ 927.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.13 MiB/6.01 MiB
# litellm    ------------------------------ 7.05 MiB/7.25 MiB
# onnxruntime ------------------------------ 8.12 MiB/15.26 MiB
# numpy      ------------------------------ 6.61 MiB/15.67 MiB
# uv         ------------------------------ 7.93 MiB/16.57 MiB
# ⠼ Preparing packages... (141/148)
# jedi       ------------------------------ 943.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.16 MiB/6.01 MiB
# litellm    ------------------------------ 7.08 MiB/7.25 MiB
# onnxruntime ------------------------------ 8.59 MiB/15.26 MiB
# numpy      ------------------------------ 7.16 MiB/15.67 MiB
# uv         ------------------------------ 8.05 MiB/16.57 MiB
# ⠼ Preparing packages... (141/148)
# jedi       ------------------------------ 943.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.19 MiB/6.01 MiB
# onnxruntime ------------------------------ 8.64 MiB/15.26 MiB
# numpy      ------------------------------ 7.37 MiB/15.67 MiB
# uv         ------------------------------ 8.32 MiB/16.57 MiB
# ⠴ Preparing packages... (142/148)
# jedi       ------------------------------ 943.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.19 MiB/6.01 MiB
# onnxruntime ------------------------------ 8.90 MiB/15.26 MiB
# numpy      ------------------------------ 7.37 MiB/15.67 MiB
# uv         ------------------------------ 8.57 MiB/16.57 MiB
# ⠴ Preparing packages... (142/148)
# jedi       ------------------------------ 943.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.32 MiB/6.01 MiB
# onnxruntime ------------------------------ 9.34 MiB/15.26 MiB
# numpy      ------------------------------ 7.52 MiB/15.67 MiB
# uv         ------------------------------ 8.92 MiB/16.57 MiB
# ⠴ Preparing packages... (142/148)
# jedi       ------------------------------ 969.07 KiB/1.50 MiB
# sympy      ------------------------------ 4.39 MiB/6.01 MiB
# onnxruntime ------------------------------ 9.73 MiB/15.26 MiB
# numpy      ------------------------------ 7.67 MiB/15.67 MiB
# uv         ------------------------------ 9.47 MiB/16.57 MiB
# ⠴ Preparing packages... (142/148)
# jedi       ------------------------------ 985.07 KiB/1.50 MiB
# sympy      ------------------------------ 4.48 MiB/6.01 MiB
# onnxruntime ------------------------------ 10.22 MiB/15.26 MiB
# numpy      ------------------------------ 7.70 MiB/15.67 MiB
# uv         ------------------------------ 9.77 MiB/16.57 MiB
# ⠦ Preparing packages... (142/148)
# jedi       ------------------------------ 985.07 KiB/1.50 MiB
# sympy      ------------------------------ 4.51 MiB/6.01 MiB
# onnxruntime ------------------------------ 10.39 MiB/15.26 MiB
# numpy      ------------------------------ 7.72 MiB/15.67 MiB
# uv         ------------------------------ 10.04 MiB/16.57 MiB
# ⠦ Preparing packages... (142/148)
# jedi       ------------------------------ 1001.07 KiB/1.50 MiB
# sympy      ------------------------------ 4.53 MiB/6.01 MiB
# onnxruntime ------------------------------ 10.69 MiB/15.26 MiB
# numpy      ------------------------------ 7.72 MiB/15.67 MiB
# uv         ------------------------------ 10.32 MiB/16.57 MiB
# ⠦ Preparing packages... (142/148)
# jedi       ------------------------------ 1007.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.67 MiB/6.01 MiB
# onnxruntime ------------------------------ 11.19 MiB/15.26 MiB
# numpy      ------------------------------ 7.72 MiB/15.67 MiB
# uv         ------------------------------ 10.82 MiB/16.57 MiB
# ⠦ Preparing packages... (142/148)
# jedi       ------------------------------ 1023.77 KiB/1.50 MiB
# sympy      ------------------------------ 4.76 MiB/6.01 MiB
# onnxruntime ------------------------------ 11.78 MiB/15.26 MiB
# numpy      ------------------------------ 7.73 MiB/15.67 MiB
# uv         ------------------------------ 11.40 MiB/16.57 MiB
# ⠦ Preparing packages... (142/148)
# jedi       ------------------------------ 1.02 MiB/1.50 MiB
# sympy      ------------------------------ 4.90 MiB/6.01 MiB
# onnxruntime ------------------------------ 12.43 MiB/15.26 MiB
# numpy      ------------------------------ 7.73 MiB/15.67 MiB
# uv         ------------------------------ 11.98 MiB/16.57 MiB
# ⠧ Preparing packages... (142/148)
# jedi       ------------------------------ 1.02 MiB/1.50 MiB
# sympy      ------------------------------ 5.01 MiB/6.01 MiB
# onnxruntime ------------------------------ 12.70 MiB/15.26 MiB
# numpy      ------------------------------ 7.73 MiB/15.67 MiB
# uv         ------------------------------ 12.44 MiB/16.57 MiB
# ⠧ Preparing packages... (142/148)
# jedi       ------------------------------ 1.03 MiB/1.50 MiB
# sympy      ------------------------------ 5.11 MiB/6.01 MiB
# onnxruntime ------------------------------ 13.14 MiB/15.26 MiB
# numpy      ------------------------------ 7.73 MiB/15.67 MiB
# uv         ------------------------------ 12.67 MiB/16.57 MiB
# ⠧ Preparing packages... (142/148)
# jedi       ------------------------------ 1.03 MiB/1.50 MiB
# sympy      ------------------------------ 5.21 MiB/6.01 MiB
# onnxruntime ------------------------------ 13.71 MiB/15.26 MiB
# numpy      ------------------------------ 7.74 MiB/15.67 MiB
# uv         ------------------------------ 13.20 MiB/16.57 MiB
# ⠧ Preparing packages... (142/148)
# jedi       ------------------------------ 1.03 MiB/1.50 MiB
# sympy      ------------------------------ 5.24 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.29 MiB/15.26 MiB
# numpy      ------------------------------ 8.03 MiB/15.67 MiB
# uv         ------------------------------ 13.73 MiB/16.57 MiB
# ⠇ Preparing packages... (142/148)
# jedi       ------------------------------ 1.04 MiB/1.50 MiB
# sympy      ------------------------------ 5.29 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.60 MiB/15.26 MiB
# numpy      ------------------------------ 8.05 MiB/15.67 MiB
# uv         ------------------------------ 14.33 MiB/16.57 MiB
# ⠇ Preparing packages... (142/148)
# jedi       ------------------------------ 1.04 MiB/1.50 MiB
# sympy      ------------------------------ 5.31 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.60 MiB/15.26 MiB
# numpy      ------------------------------ 9.85 MiB/15.67 MiB
# uv         ------------------------------ 14.50 MiB/16.57 MiB
# ⠇ Preparing packages... (142/148)
# jedi       ------------------------------ 1.06 MiB/1.50 MiB
# sympy      ------------------------------ 5.35 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.63 MiB/15.26 MiB
# numpy      ------------------------------ 10.05 MiB/15.67 MiB
# uv         ------------------------------ 15.31 MiB/16.57 MiB
# ⠇ Preparing packages... (142/148)
# jedi       ------------------------------ 1.06 MiB/1.50 MiB
# sympy      ------------------------------ 5.35 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.63 MiB/15.26 MiB
# numpy      ------------------------------ 11.12 MiB/15.67 MiB
# uv         ------------------------------ 15.83 MiB/16.57 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.37 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# numpy      ------------------------------ 12.12 MiB/15.67 MiB
# uv         ------------------------------ 16.53 MiB/16.57 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.39 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# numpy      ------------------------------ 12.67 MiB/15.67 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.40 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.43 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.43 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# ⠋ Preparing packages... (142/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.49 MiB/6.01 MiB
# onnxruntime ------------------------------ 14.71 MiB/15.26 MiB
# ⠙ Preparing packages... (144/148)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# sympy      ------------------------------ 5.51 MiB/6.01 MiB
# ⠙ Preparing packages... (144/148)
# jedi       ------------------------------ 1.09 MiB/1.50 MiB
# sympy      ------------------------------ 5.51 MiB/6.01 MiB
# ⠙ Preparing packages... (144/148)
# jedi       ------------------------------ 1.12 MiB/1.50 MiB
# sympy      ------------------------------ 5.76 MiB/6.01 MiB
# ⠙ Preparing packages... (144/148)
# jedi       ------------------------------ 1.15 MiB/1.50 MiB
# ⠙ Preparing packages... (144/148)
# jedi       ------------------------------ 1.15 MiB/1.50 MiB
# ⠙ Preparing packages... (144/148)
# Prepared 148 packages in 7.44s
# Installed 148 packages in 647ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.18
#  + aiosignal==1.3.2
#  + annotated-types==0.7.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + auth0-python==4.9.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.4.26
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + chroma-hnswlib==0.7.6
#  + chromadb==1.0.7
#  + click==8.1.8
#  + coloredlogs==15.0.1
#  + crewai==0.118.0
#  + cryptography==44.0.3
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + distro==1.9.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.9
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.6.0
#  + fsspec==2025.3.2
#  + google-auth==2.39.0
#  + googleapis-common-protos==1.70.0
#  + grpcio==1.71.0
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + huggingface-hub==0.30.2
#  + humanfriendly==10.0
#  + idna==3.10
#  + importlib-metadata==8.6.1
#  + importlib-resources==6.5.2
#  + instructor==1.7.9
#  + ipython==9.2.0
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.44.1
#  + json5==0.12.0
#  + jsonpickle==4.0.5
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==32.0.1
#  + litellm==1.67.1
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mmh3==5.1.0
#  + mpmath==1.3.0
#  + multidict==6.4.3
#  + networkx==3.4.2
#  + numpy==2.2.5
#  + oauthlib==3.2.2
#  + onnxruntime==1.21.1
#  + openai==1.77.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.32.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-exporter-otlp-proto-http==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  + opentelemetry-sdk==1.32.1
#  + opentelemetry-semantic-conventions==0.53b1
#  + opentelemetry-util-http==0.53b1
#  + orjson==3.10.18
#  + overrides==7.7.0
#  + packaging==25.0
#  + parso==0.8.4
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + pexpect==4.9.0
#  + pillow==11.2.1
#  + posthog==4.0.1
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.1
#  + protobuf==5.29.4
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.4
#  + pydantic-core==2.33.2
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + rich==13.9.4
#  + rpds-py==0.24.0
#  + rsa==4.9.1
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + stack-data==0.6.3
#  + starlette==0.45.3
#  + sympy==1.14.0
#  + tenacity==9.1.2
#  + tiktoken==0.9.0
#  + tokenizers==0.21.1
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.3
#  + typing-extensions==4.13.2
#  + typing-inspection==0.4.0
#  + urllib3==2.4.0
#  + uv==0.7.2
#  + uvicorn==0.34.2
#  + uvloop==0.21.0
#  + watchfiles==1.0.5
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.20.0
#  + zipp==3.21.0
# Installed 1 executable: crewai
# warning: `/root/.local/bin` is not on your PATH. To use installed tools, run `export PATH="/root/.local/bin:$PATH"` or `uv tool update-shell`.
# Resolved 148 packages in 545ms
# Audited 148 packages in 0.16ms
# Installed 1 executable: crewai
# warning: `/root/.local/bin` is not on your PATH. To use installed tools, run `export PATH="/root/.local/bin:$PATH"` or `uv tool update-shell`.
# crewai v0.118.0
# - crewai
# Updated configuration file: /root/.profile
# Updated configuration file: /root/.bashrc
# Restart your shell to apply changes
# Creating folder newsletter_agent...
# Cache expired or not found. Fetching provider data from the web...
# Downloading  [####################################]  449025/21806
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. huggingface
# 7. ollama
# 8. watson
# 9. bedrock
# 10. azure
# 11. cerebras
# 12. sambanova
# 13. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Select a model to use for Openai:
# 1. gpt-4
# 2. gpt-4.1
# 3. gpt-4.1-mini-2025-04-14
# 4. gpt-4.1-nano-2025-04-14
# 5. gpt-4o
# 6. gpt-4o-mini
# 7. o1-mini
# 8. o1-preview
# q. Quit
# Enter the number of your choice or 'q' to quit: 6
# Enter your OPENAI API key (press Enter to skip): sk-proj-zhLv3eJaKdmTKNJwRNlbT3BlbkFJ2pdHw6Vr9xgsuLA9T0DV
# API keys and model saved to .env file
# Selected model: gpt-4o-mini
#   - Created newsletter_agent/.gitignore
#   - Created newsletter_agent/pyproject.toml
#   - Created newsletter_agent/README.md
#   - Created newsletter_agent/knowledge/user_preference.txt
#   - Created newsletter_agent/src/newsletter_agent/__init__.py
#   - Created newsletter_agent/src/newsletter_agent/main.py
#   - Created newsletter_agent/src/newsletter_agent/crew.py
#   - Created newsletter_agent/src/newsletter_agent/tools/custom_tool.py
#   - Created newsletter_agent/src/newsletter_agent/tools/__init__.py
#   - Created newsletter_agent/src/newsletter_agent/config/agents.yaml
#   - Created newsletter_agent/src/newsletter_agent/config/tasks.yaml
# Crew newsletter_agent created successfully!
# error: No `pyproject.toml` found in current directory or any parent directory
# An error occurred while running the crew: Command '['uv', 'sync']' returned non-zero exit status 2.

# %%
# Criar a pasta (caso ainda não exista)
# !mkdir -p newsletter_agent

# Mudar para a pasta e mostrar conteúdo (simulando cd)
# %cd newsletter_agent
# Verificar se está na pasta correta
# !pwd
# Out:
# /content/newsletter_agent
# /content/newsletter_agent

# %%
# !uv add pydantic
# Out:
# Resolved 206 packages in 1.60s
#    Building newsletter-agent @ file:///content/newsletter_agent
#    Building newsletter-agent @ file:///content/newsletter_agent
#    Building newsletter-agent @ file:///content/newsletter_agent
#    Building newsletter-agent @ file:///content/newsletter_agent
#       Built newsletter-agent @ file:///content/newsletter_agent
# Prepared 1 package in 648ms
# Uninstalled 1 package in 0.61ms
# Installed 1 package in 1ms
#  ~ newsletter-agent==0.1.0 (from file:///content/newsletter_agent)

# %%
# !crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: a9a634af-9071-4a05-9256-87492e6f4b64                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
#        Status: Executing Task...
#
# 🚀 Crew: crew
# └── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: In Progress
#
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2025.
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
# └── 🧠 Thinking...
#
# 🤖 Agent: AI LLMs Senior Data Researcher
#
#     Status: In Progress
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. **Advancements in Fine-Tuning Techniques**: As of 2025, AI LLMs have seen significant enhancements in fine-tuning methodologies, allowing them to adapt more effectively to specific tasks and domains. This includes techniques like prompt engineering, where users can customize inputs to elicit desired outputs.
#
# 2. **Ethical and Responsible AI**: The discourse around AI ethics has evolved, particularly regarding the mitigation of biases in LLM outputs. New frameworks and guidelines are now in place to ensure LLMs operate fairly and transparently, addressing issues such as representation and accountability.
#
# 3. **Integration of Multimodal Capabilities**: Modern LLMs are increasingly capable of processing and generating data across multiple modalities, including text, images, and audio. This integration allows for richer interactions and more sophisticated applications in fields like education and healthcare.
#
# 4. **Performance on Low-Resource Languages**: There has been a notable push to enhance language models' performance on low-resource languages, using techniques such as transfer learning and multilingual training. This development aims to ensure wider accessibility and usability across diverse linguistic contexts.
#
# 5. **Energy Efficiency and Sustainability**: In response to growing concerns about the carbon footprint of large-scale models, researchers have developed more energy-efficient training methods. Techniques such as model distillation and pruning are allowing LLMs to maintain performance while reducing resource consumption.
#
# 6. **Real-Time Collaboration Tools**: AI LLMs are being integrated into collaborative environments, enhancing productivity tools by providing real-time suggestions and automating routine tasks. This has led to improvements in team workflows across numerous industries.
#
# 7. **Open Source Models Dominating the Market**: The trend towards open-source large language models has gained momentum, with several organizations releasing robust models that compete with proprietary counterparts. This trend is democratizing access to advanced AI technologies.
#
# 8. **Utility in Code Generation**: LLMs have made strides in code generation, helping developers write code faster and more efficiently by understanding context, fixing bugs, and even suggesting enhancements, thus facilitating a smoother software development lifecycle.
#
# 9. **Human-like Conversational Abilities**: The latest iterations of LLMs have achieved remarkable human-like conversational capabilities, enabling them to engage in more meaningful dialogues, understand context better, and provide more relevant answers to user inquiries.
#
# 10. **Regulatory Frameworks under Development**: As AI LLMs continue to proliferate, governments and organizations are devising regulatory frameworks to govern their use, aiming to prevent misuse while fostering innovation and ensuring safety in AI applications.
#
# These points reflect the cutting-edge landscape of AI LLMs in 2025, capturing the most impactful developments and trends shaping the future of this technology.
#
#
# 🚀 Crew: crew
# └── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# └── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
#        Assigned to: AI LLMs Senior Data Researcher
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Senior Data Researcher
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: c30cc93e-220f-427f-8b10-ee5cd9338a1e                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: In Progress
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Report on the Advancements and Current Landscape of AI LLMs in 2025
#
# ## 1. Advancements in Fine-Tuning Techniques
# As of 2025, AI large language models (LLMs) have undergone significant advancements in fine-tuning methodologies. These enhancements facilitate more effective adaptation to specific tasks and domains, allowing for tailored responses based on user inputs. One notable technique is prompt engineering, wherein users customize input prompts to guide the model towards generating desired outputs. This process not only improves the relevance of responses but also allows users to leverage LLMs for niche applications, making them versatile tools in various sectors such as finance, healthcare, and customer service. Furthermore, ongoing research in this area continues to explore adaptive learning algorithms, which enable models to adjust their parameters dynamically based on real-time feedback, enhancing their performance on specific tasks.
#
# ## 2. Ethical and Responsible AI
# The conversation around AI ethics has significantly evolved, emphasizing the necessity for AI systems to operate fairly and transparently. By 2025, new frameworks and guidelines have been created to mitigate biases inherent in LLM outputs. These initiatives focus on enhancing representation, accountability, and the ethical use of data. Stakeholders are increasingly recognizing the need for diverse datasets that reflect different demographics, thus minimizing the risk of biased or harmful outputs. Moreover, organizations are adopting ethical audits and bias detection algorithms to ensure compliance with ethical standards, ultimately fostering public trust and promoting a responsible AI ecosystem.
#
# ## 3. Integration of Multimodal Capabilities
# Modern LLMs are making strides in integrating multimodal capabilities, allowing them to process and generate data across various formats, including text, images, and audio. This advancement has significant implications for enhancing user interactions and creating sophisticated applications. In sectors such as education, healthcare, and entertainment, LLMs can provide richer content experiences, such as generating descriptive captions for images or synthesizing educational materials that combine text and visuals. This multidimensional processing fosters a more engaging and effective communication channel between users and AI systems.
#
# ## 4. Performance on Low-Resource Languages
# There has been a significant push to enhance the performance of language models, particularly with respect to low-resource languages, whose linguistic diversity often goes unaddressed. In 2025, techniques such as transfer learning and multilingual training are employed to ensure that LLMs can function across a broader range of languages. This development aims to promote accessibility and usability, ensuring that non-English-speaking communities can leverage AI technologies effectively. Collaborations with linguistic experts and local communities enhance the models' understanding of cultural nuances and contextual relevance, empowering users worldwide.
#
# ## 5. Energy Efficiency and Sustainability
# In light of growing concerns about the environmental impact of large-scale AI models, researchers are focusing on developing energy-efficient training methods. By 2025, techniques such as model distillation and pruning have emerged, allowing LLMs to retain their performance levels while significantly reducing their resource consumption. These innovations are crucial in mitigating the carbon footprint associated with AI, contributing to sustainability efforts across the technology sector. Many organizations are now prioritizing these eco-friendly practices, reflecting a commitment to responsible resource management and sustainable innovation.
#
# ## 6. Real-Time Collaboration Tools
# The integration of AI LLMs into collaborative environments has become a game changer for productivity tools. In 2025, LLMs are providing real-time suggestions, automating routine tasks, and facilitating smoother workflows across various industries. By assisting teams with brainstorming sessions, document drafting, and project management, LLMs are enhancing collaborative efforts and allowing for more effective communication. This advancement not only increases efficiency but also enriches the creativity and innovation within teams, fostering a more agile working environment.
#
# ## 7. Open Source Models Dominating the Market
# The trend toward open-source large language models has gained traction, with numerous organizations releasing competitive models that rival proprietary options. By 2025, this shift is democratizing access to advanced AI technologies, allowing smaller enterprises and individuals to leverage powerful LLMs without prohibitive costs. This movement encourages community collaboration and innovation, as developers contribute to the ongoing improvement of open-source models. The accessibility of these resources is fostering a vibrant ecosystem of creativity and experimentation in the AI domain.
#
# ## 8. Utility in Code Generation
# LLMs have made considerable strides in the area of code generation, proving to be invaluable tools for developers. By 2025, these models assist in writing code more quickly and effectively by understanding context, fixing bugs, and suggesting enhancements based on established coding practices. This capability not only accelerates the software development lifecycle but also improves overall code quality. As developers increasingly rely on LLMs for programming tasks, the landscape of software development is transforming, fostering greater efficiency and innovation.
#
# ## 9. Human-like Conversational Abilities
# The latest iterations of LLMs showcase remarkable advancements in achieving human-like conversational capabilities. These models are adept at engaging in meaningful dialogues, understanding nuanced context, and generating more relevant and personalized responses to inquiries. As the line between human and machine interaction continues to blur, users benefit from enhanced experiences across various platforms, such as customer service, virtual assistants, and social media. This evolution marks a significant step towards creating more intuitive and effective communication channels between humans and AI.
#
# ## 10. Regulatory Frameworks under Development
# As AI LLMs continue to proliferate, it has become increasingly important for governments and organizations to develop regulatory frameworks governing their use. By 2025, various stakeholders are actively engaged in creating policies aimed at preventing misuse, while fostering innovation and ensuring the safety of AI applications. These frameworks focus on establishing standards for transparency, accountability, and ethical conduct in AI development and deployment. By addressing concerns surrounding user privacy, data security, and algorithmic fairness, the regulatory landscape aims to promote public confidence and responsible usage of AI technologies.
#
# This report outlines the cutting-edge advancements and trends shaping the landscape of AI LLMs as of 2025, reflecting the most impactful developments influencing the future of this transformative technology.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# └── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
#        Assigned to: AI LLMs Reporting Analyst
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Reporting Analyst
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 5eb4b2d1-732e-4d79-8685-65682f34bd5a                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# ├── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
# │      Assigned to: AI LLMs Reporting Analyst
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Reporting Analyst
# │
# │           Status: ✅ Completed
# └── 📋 Task: 28468233-cd5f-4db1-accc-7cb1b0bbc753
#        Status: Executing Task...
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# ├── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
# │      Assigned to: AI LLMs Reporting Analyst
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Reporting Analyst
# │
# │           Status: ✅ Completed
# └── 📋 Task: 28468233-cd5f-4db1-accc-7cb1b0bbc753
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Newsletter Content Writer
#
#             Status: In Progress
#
# # Agent: AI LLMs Newsletter Content Writer
# ## Task: Escreva um resumo de newsletter com base nas descobertas da pesquisa sobre AI LLMs
#
#
#
# # Agent: AI LLMs Newsletter Content Writer
# ## Final Answer:
# Nesta edição da nossa newsletter, exploramos as principais descobertas sobre os avanços dos modelos de linguagem de inteligência artificial (LLMs) em 2025. Com melhorias significativas nas técnicas de fine-tuning, os LLMs agora se adaptam melhor a tarefas específicas por meio de engenharia de prompts, permitindo uma maior personalização nas respostas. A ética e a responsabilidade na IA continuam a ser questões centrais, evidenciadas por novas diretrizes que buscam mitigar preconceitos nos resultados dos modelos. Adicionalmente, as capacidades multimodais estão enriquecendo a interação entre humanos e LLMs, ao permitir a geração de dados em texto, imagem e áudio. Outra iniciativa digna de nota é a ênfase no desempenho em línguas de baixo recurso, tornando essas ferramentas mais inclusivas. Além disso, avanços em eficiência energética refletem um compromisso com a sustentabilidade ambiental, enquanto a integração de LLMs em ferramentas de colaboração em tempo real transforma fluxos de trabalho. O crescimento de modelos de código aberto democratiza o acesso às tecnologias de IA, e as habilidades de geração de código estão acelerando o desenvolvimento de software. Com conversas cada vez mais humanas e a elaboração de estruturas regulatórias, o cenário da IA LLM está em rápida evolução, prometendo um futuro inovador e ético no uso dessa poderosa tecnologia.
#
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# ├── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
# │      Assigned to: AI LLMs Reporting Analyst
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Reporting Analyst
# │
# │           Status: ✅ Completed
# └── 📋 Task: 28468233-cd5f-4db1-accc-7cb1b0bbc753
#        Status: Executing Task...
#     └── 🤖 Agent: AI LLMs Newsletter Content Writer
#
#             Status: ✅ Completed
#
# 🚀 Crew: crew
# ├── 📋 Task: c30cc93e-220f-427f-8b10-ee5cd9338a1e
# │      Assigned to: AI LLMs Senior Data Researcher
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Senior Data Researcher
# │
# │           Status: ✅ Completed
# ├── 📋 Task: 5eb4b2d1-732e-4d79-8685-65682f34bd5a
# │      Assigned to: AI LLMs Reporting Analyst
# │
# │      Status: ✅ Completed
# │   └── 🤖 Agent: AI LLMs Reporting Analyst
# │
# │           Status: ✅ Completed
# └── 📋 Task: 28468233-cd5f-4db1-accc-7cb1b0bbc753
#        Assigned to: AI LLMs Newsletter Content Writer
#
#        Status: ✅ Completed
#     └── 🤖 Agent: AI LLMs Newsletter Content Writer
#
#             Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 28468233-cd5f-4db1-accc-7cb1b0bbc753                                  │
# │  Agent: AI LLMs Newsletter Content Writer                                    │
# │                                                                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: a9a634af-9071-4a05-9256-87492e6f4b64                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
